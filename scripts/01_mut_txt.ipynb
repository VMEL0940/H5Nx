# %%
import os
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Align import PairwiseAligner
from Bio.SeqUtils import nt_search
from Bio.SeqIO import write
from itertools import combinations
import numpy as np
import pandas as pd
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import pairwise_distances
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def convert_to_three_letter(aa):
    """Convert single-letter amino acid code to three-letter code."""
    aa_dict = {
        "A" : "ALA", "R" : "ARG", "N" : "ASN", "D" : "ASP", "C" : "CYS", 
        "Q" : "GLN", "E" : "GLU", "G" : "GLY", "H" : "HIS", "I" : "ILE", 
        "L" : "LEU", "K" : "LYS", "M" : "MET", "F" : "PHE", "P" : "PRO", 
        "S" : "SER", "T" : "THR", "W" : "TRP", "Y" : "TYR", "V" : "VAL"
    }
    return aa_dict.get(aa, "Unknown")

def compare_sequences(test_seq, ref_seq, start_pos):
    """
    Compare two sequences and identify mutations, adjusting positions with an offset.
    
    Parameters:
    - test_seq: str, the sequence to be tested
    - ref_seq: str, the reference sequence
    - start_pos: int, start_pos offset for mutation numbering
    
    Returns:
    - str: A string of mutations in the format "A:<position> <reference_3letter> -> <test_3letter>"
    """
    # Ensure the sequences are the same length
    if len(test_seq) != len(ref_seq):
        raise ValueError("Sequences must be of the same length")
    
    # Initialize a list to store positions of differences
    mutations = []
    
    # Loop through each position and compare residues
    for i in range(len(ref_seq)):
        # Skip positions where either sequence has 'X'
        if ref_seq[i] == "X" or test_seq[i] == "X":
            continue
        if ref_seq[i] != test_seq[i]:
            ref_aa_3letter = convert_to_three_letter(ref_seq[i])
            test_aa_3letter = convert_to_three_letter(test_seq[i])
            mutations.append(f"A:{i + start_pos}->{test_aa_3letter}")
    
    # Return the mutations as a single string
    return " ".join(mutations)

# %%
# Read sequences from the FASTA file
def read_sequences(file_path):
    """Read sequences from a FASTA file."""
    sequences = list(SeqIO.parse(file_path, "fasta"))
    for seq in sequences:
        seq.seq = Seq(str(seq.seq).replace("-", "X"))  # Replace '-' with X'
    return sequences

# Subset sequences
def subset_sequences(sequences, start, end):
    """Extract a subsequence from a list of sequences."""
    subset = []
    for seq in sequences:
        sub_seq = seq.seq[start-1:end]  # Convert to 0-based indexing
        subset.append(SeqRecord(sub_seq, id=seq.id, description=""))
    return subset

# %%
def extract_sequences_with_x(sequences):
    """
    Extract sequences that contain the residue 'X'.
    
    Parameters:
    - sequences: list of str, a list of sequences
    
    Returns:
    - list of str: A list of sequences that contain 'X'
    """
    return [seq for seq in sequences if "X" in seq]
def get_complementary_set(test_seq, seq_with_del):
    """
    Get the complementary set of sequences by removing the sequences in seq_with_del from test_seq.
    Always returns the complementary set as SeqRecord objects with meaningful IDs.

    Parameters:
    - test_seq: list of SeqRecord, the original set of sequences
    - seq_with_del: list of SeqRecord, the set of sequences to be excluded

    Returns:
    - list of SeqRecord: The complementary set of sequences with IDs.
    """
    # Create a list of (sequence string, ID) pairs for test_seq
    test_seq_list = [(str(seq.seq), seq.id) for seq in test_seq]
    
    # Create a Counter for test_seq
    test_seq_counts = Counter(test_seq_list)
    
    # Create a Counter for seq_with_del
    seq_with_del_list = [(str(seq.seq), seq.id) for seq in seq_with_del]
    seq_with_del_counts = Counter(seq_with_del_list)
    
    # Subtract the counts
    complementary_counts = test_seq_counts - seq_with_del_counts
    
    # Reconstruct the complementary set as SeqRecord objects
    complementary_sequences = []
    for (seq_str, seq_id), count in complementary_counts.items():
        for _ in range(count):
            complementary_sequences.append(SeqRecord(Seq(seq_str), id=seq_id))
    
    return complementary_sequences

def cluster_sequences_by_position(sequences, position, target_char="X"):
    """
    Cluster sequences based on whether they contain a specific character at a given position.

    Parameters:
    - sequences: list of SeqRecord, the sequences to be clustered.
    - position: int, the 1-based position to check (e.g., 145).
    - target_char: str, the character to match (default is "X").

    Returns:
    - dict: A dictionary with two keys:
        - "contains_target": list of SeqRecord containing the target_char at the position.
        - "does_not_contain_target": list of SeqRecord not containing the target_char at the position.
    """
    contains_target = []

    for seq_record in sequences:
        sequence = str(seq_record.seq)
        # Ensure the position is within the sequence length
        if position - 1 < len(sequence) and sequence[position - 1] == target_char:  # 1-based index to 0-based index
            contains_target.append(seq_record)
    return contains_target

# %%
cur_dir = '/Volumes/shared610/Swine_Host/'
out_dir = '/Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8'

# %%
fasta_file = cur_dir + 'FASTA_collection/NA/N8_unique.fasta'
ref_file = cur_dir + 'GsGd_residual_scanning/Ref/N8_EPI734757.fasta'

# %%
#Extracting binding sites from the entire sequence
start = 1
end = 387
test_seq_full = read_sequences(fasta_file)
test_seq = subset_sequences(test_seq_full, start, end)
ref_seq_full = read_sequences(ref_file)
ref_seq = subset_sequences(ref_seq_full,start, end)

# %%
seq_with_del = extract_sequences_with_x(test_seq)
test_seq_with_full = get_complementary_set(test_seq, seq_with_del)

seq_with_del142 = cluster_sequences_by_position(test_seq_full, 142, target_char="X")
seq_with_del143 = cluster_sequences_by_position(test_seq_full, 143, target_char="X")
seq_with_del144 = cluster_sequences_by_position(test_seq_full, 144, target_char="X")

test_seq_with_del142 = subset_sequences(seq_with_del142, start, end)
test_seq_with_del143 = subset_sequences(seq_with_del143, start, end)
test_seq_with_del144 = subset_sequences(seq_with_del144, start, end)

# %% [markdown]
# Extracting the mutations compared with reference sequence.

# %%
# Numbering adjustment for PDB file
position = 83

# %%
# Initialize a dictionary to store mutations for each test sequence
all_mutations = {}
ref_seq_str = str(ref_seq[0].seq)
group = "N8"
for i, seq_record in enumerate(test_seq):
    test_seq_str = str(seq_record.seq)  # Convert current test_seq to a string
    seq_name = seq_record.id 

    # Check if lengths match
    if len(test_seq_str) != len(ref_seq_str):
        print(f"Skipping sequence {i+1}: Length mismatch (test: {len(test_seq_str)}, ref: {len(ref_seq_str)})")
        continue
    
    # Compare sequences and store results
    mutations = compare_sequences(test_seq_str, ref_seq_str, position)
    
    # Parse the accession number (acc) from the sequence name
    try:
        _, _, acc, _ = seq_name.split("|")
    except ValueError:
        print(f"Unable to parse sequence name: {seq_name}")
        acc = f"sequence_{i+1}"  # Fallback name
    
    # Define the output file name using only "acc"
    output_file = os.path.join(out_dir, f"{group}_{acc}.txt")
    
    # Save mutations to the output file
    with open(output_file, "w") as f:
        f.write(mutations)

    print(f"Saved mutations for {acc} to {output_file}.")
# Out:
# Saved mutations for EPI1846961 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1846961.txt.
# Saved mutations for EPI1858930 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1858930.txt.
# Saved mutations for EPI1916410 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1916410.txt.
# Saved mutations for EPI1918889 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1918889.txt.
# Saved mutations for EPI1918893 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1918893.txt.
# Saved mutations for EPI1918903 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1918903.txt.
# Saved mutations for EPI867108 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI867108.txt.
# Saved mutations for EPI1185037 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1185037.txt.
# Saved mutations for EPI861011 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI861011.txt.
# Saved mutations for MN759487 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MN759487.txt.
# Saved mutations for MK168599 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MK168599.txt.
# Saved mutations for MZ166252 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MZ166252.txt.
# Saved mutations for MK631789 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MK631789.txt.
# Saved mutations for ON171655 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_ON171655.txt.
# Saved mutations for MT261396 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MT261396.txt.
# Saved mutations for MT261424 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MT261424.txt.
# Saved mutations for MT261579 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MT261579.txt.
# Saved mutations for OL354574 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_OL354574.txt.
# Saved mutations for LC699656 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_LC699656.txt.
# Saved mutations for MH165524 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MH165524.txt.
# Saved mutations for OQ794112 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_OQ794112.txt.
# Saved mutations for OQ794093 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_OQ794093.txt.
# Saved mutations for MW342700 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MW342700.txt.
# Saved mutations for LC656652 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_LC656652.txt.
# Saved mutations for MH498632 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MH498632.txt.
# Saved mutations for EPI1956648 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1956648.txt.
# Saved mutations for EPI1943861 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1943861.txt.
# Saved mutations for EPI1848678 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1848678.txt.
# Saved mutations for EPI1848798 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1848798.txt.
# Saved mutations for EPI1800003 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1800003.txt.
# Saved mutations for EPI1859637 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1859637.txt.
# Saved mutations for EPI1846025 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1846025.txt.
# Saved mutations for EPI2001588 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI2001588.txt.
# Saved mutations for EPI1944162 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1944162.txt.
# Saved mutations for EPI1859333 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1859333.txt.
# Saved mutations for EPI1917366 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1917366.txt.
# Saved mutations for EPI1814660 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1814660.txt.
# Saved mutations for EPI1843650 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1843650.txt.
# Saved mutations for EPI1860063 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1860063.txt.
# Saved mutations for EPI2782336 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI2782336.txt.
# Saved mutations for EPI2782360 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI2782360.txt.
# Saved mutations for EPI1868456 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1868456.txt.
# Saved mutations for EPI1850136 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1850136.txt.
# Saved mutations for EPI2152295 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI2152295.txt.
# Saved mutations for EPI1807331 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1807331.txt.
# Saved mutations for EPI1858590 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1858590.txt.
# Saved mutations for EPI1859663 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1859663.txt.
# Saved mutations for EPI1954384 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1954384.txt.
# Saved mutations for EPI1921574 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1921574.txt.
# Saved mutations for EPI1944216 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1944216.txt.
# Saved mutations for EPI1854323 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1854323.txt.
# Saved mutations for EPI1854331 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1854331.txt.
# Saved mutations for EPI1944187 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1944187.txt.
# Saved mutations for EPI1944183 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1944183.txt.
# Saved mutations for EPI1811601 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1811601.txt.
# Saved mutations for EPI1858500 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1858500.txt.
# Saved mutations for EPI1858468 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1858468.txt.
# Saved mutations for EPI1877870 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1877870.txt.
# Saved mutations for EPI1815191 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1815191.txt.
# Saved mutations for EPI1159809 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1159809.txt.
# Saved mutations for EPI907346 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI907346.txt.
# Saved mutations for EPI1701675 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1701675.txt.
# Saved mutations for EPI1701629 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1701629.txt.
# Saved mutations for EPI1701733 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1701733.txt.
# Saved mutations for EPI1081925 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1081925.txt.
# Saved mutations for EPI1007667 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1007667.txt.
# Saved mutations for EPI836614 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI836614.txt.
# Saved mutations for EPI1802161 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1802161.txt.
# Saved mutations for EPI1184965 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1184965.txt.
# Saved mutations for EPI1184995 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1184995.txt.
# Saved mutations for EPI1185024 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1185024.txt.
# Saved mutations for EPI1021093 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1021093.txt.
# Saved mutations for EPI1021094 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1021094.txt.
# Saved mutations for EPI1669669 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1669669.txt.
# Saved mutations for EPI952639 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI952639.txt.
# Saved mutations for EPI954567 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI954567.txt.
# Saved mutations for EPI954591 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI954591.txt.
# Saved mutations for EPI863849 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI863849.txt.
# Saved mutations for EPI1721802 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1721802.txt.
# Saved mutations for EPI1123343 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1123343.txt.
# Saved mutations for EPI1737049 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1737049.txt.
# Saved mutations for EPI1737147 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1737147.txt.
# Saved mutations for EPI1737155 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1737155.txt.
# Saved mutations for EPI961475 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI961475.txt.
# Saved mutations for EPI869926 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI869926.txt.
# Saved mutations for EPI873624 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI873624.txt.
# Saved mutations for EPI973841 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI973841.txt.
# Saved mutations for EPI1585011 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1585011.txt.
# Saved mutations for EPI1585019 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1585019.txt.
# Saved mutations for EPI1144101 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1144101.txt.
# Saved mutations for EPI1226468 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1226468.txt.
# Saved mutations for EPI1682667 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1682667.txt.
# Saved mutations for KJ508916 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_KJ508916.txt.
# Saved mutations for MW333286 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MW333286.txt.
# Saved mutations for MW333558 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MW333558.txt.
# Saved mutations for MW333646 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MW333646.txt.
# Saved mutations for MW333774 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_MW333774.txt.
# Saved mutations for EPI595079 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI595079.txt.
# Saved mutations for EPI595124 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI595124.txt.
# Saved mutations for EPI561187 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI561187.txt.
# Saved mutations for EPI690131 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI690131.txt.
# Saved mutations for EPI509698 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI509698.txt.
# Saved mutations for EPI573171 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI573171.txt.
# Saved mutations for EPI573672 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI573672.txt.
# Saved mutations for EPI576384 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI576384.txt.
# Saved mutations for EPI703595 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI703595.txt.
# Saved mutations for EPI1681724 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1681724.txt.
# Saved mutations for EPI1681906 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI1681906.txt.
# Saved mutations for EPI734757 to /Volumes/shared610/Swine_Host/GsGd_residual_scanning/N8/N8_EPI734757.txt.
